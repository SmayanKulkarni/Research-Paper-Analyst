# %%
import fitz  # PyMuPDF
import os

def extract_images(pdf_path, output_folder="extracted_images"):
    os.makedirs(output_folder, exist_ok=True)
    pdf = fitz.open(pdf_path)

    img_num = 0
    for page_index in range(len(pdf)):
        page = pdf[page_index]
        images = page.get_images(full=True)

        for img in images:
            xref = img[0]
            base_image = pdf.extract_image(xref)
            image_bytes = base_image["image"]
            image_ext = base_image["ext"]
            img_num += 1

            image_path = os.path.join(output_folder, f"image_{img_num}.{image_ext}")
            with open(image_path, "wb") as f:
                f.write(image_bytes)

            print(f"Saved {image_path}")

    pdf.close()

# Example
extract_images("/home/smayan/Desktop/Research-Paper-Analyst/downloads/1906.00744v5.pdf")
# Out:
# Saved extracted_images/image_1.png
# Saved extracted_images/image_2.png
# Saved extracted_images/image_3.png
# Saved extracted_images/image_4.png
# Saved extracted_images/image_5.png
# Saved extracted_images/image_6.png
# Saved extracted_images/image_7.png
# Saved extracted_images/image_8.png
# Saved extracted_images/image_9.png
# Saved extracted_images/image_10.png
# Saved extracted_images/image_11.png
# Saved extracted_images/image_12.png
# Saved extracted_images/image_13.png
# Saved extracted_images/image_14.png
# Saved extracted_images/image_15.png
# Saved extracted_images/image_16.png
# Saved extracted_images/image_17.png
# Saved extracted_images/image_18.png
# Saved extracted_images/image_19.png
# Saved extracted_images/image_20.png
# Saved extracted_images/image_21.png
# Saved extracted_images/image_22.png
# Saved extracted_images/image_23.png
# Saved extracted_images/image_24.png
# Saved extracted_images/image_25.png
# Saved extracted_images/image_26.png
# Saved extracted_images/image_27.png
# Saved extracted_images/image_28.png
# Saved extracted_images/image_29.png
# Saved extracted_images/image_30.png
# Saved extracted_images/image_31.png
# Saved extracted_images/image_32.png
# Saved extracted_images/image_33.png
# Saved extracted_images/image_34.png
# Saved extracted_images/image_35.png
# Saved extracted_images/image_36.png
# Saved extracted_images/image_37.png
# Saved extracted_images/image_38.png
# Saved extracted_images/image_39.png
# Saved extracted_images/image_40.png
# Saved extracted_images/image_41.png
# Saved extracted_images/image_42.png
# Saved extracted_images/image_43.png
# Saved extracted_images/image_44.png
# Saved extracted_images/image_45.png
# Saved extracted_images/image_46.png
# Saved extracted_images/image_47.png
# Saved extracted_images/image_48.png
# Saved extracted_images/image_49.png
# Saved extracted_images/image_50.png
# Saved extracted_images/image_51.png
# Saved extracted_images/image_52.png
# Saved extracted_images/image_53.png
# Saved extracted_images/image_54.png
# Saved extracted_images/image_55.png
# Saved extracted_images/image_56.png
# Saved extracted_images/image_57.png
# Saved extracted_images/image_58.png
# Saved extracted_images/image_59.png
# Saved extracted_images/image_60.png
# Saved extracted_images/image_61.png
# Saved extracted_images/image_62.png
# Saved extracted_images/image_63.png
# Saved extracted_images/image_64.png
# Saved extracted_images/image_65.png
# Saved extracted_images/image_66.png
# Saved extracted_images/image_67.png
# Saved extracted_images/image_68.png
# Saved extracted_images/image_69.png
# Saved extracted_images/image_70.png
# Saved extracted_images/image_71.png
# Saved extracted_images/image_72.png
# Saved extracted_images/image_73.png
# Saved extracted_images/image_74.png
# Saved extracted_images/image_75.png
# Saved extracted_images/image_76.png
# Saved extracted_images/image_77.png
# Saved extracted_images/image_78.png
# Saved extracted_images/image_79.png
# Saved extracted_images/image_80.png
# Saved extracted_images/image_81.png
# Saved extracted_images/image_82.png
# Saved extracted_images/image_83.png
# Saved extracted_images/image_84.png
# Saved extracted_images/image_85.png
# Saved extracted_images/image_86.png
# Saved extracted_images/image_87.png
# Saved extracted_images/image_88.png
# Saved extracted_images/image_89.png
# Saved extracted_images/image_90.png
# Saved extracted_images/image_91.png
# Saved extracted_images/image_92.png
# Saved extracted_images/image_93.png
# Saved extracted_images/image_94.png
# Saved extracted_images/image_95.png
# Saved extracted_images/image_96.png
# Saved extracted_images/image_97.png
# Saved extracted_images/image_98.png
# Saved extracted_images/image_99.png
# Saved extracted_images/image_100.png
# Saved extracted_images/image_101.png
# Saved extracted_images/image_102.png
# Saved extracted_images/image_103.png
# Saved extracted_images/image_104.png
# Saved extracted_images/image_105.png
# Saved extracted_images/image_106.png
# Saved extracted_images/image_107.png
# Saved extracted_images/image_108.png
# Saved extracted_images/image_109.png
# Saved extracted_images/image_110.png
# Saved extracted_images/image_111.png
# Saved extracted_images/image_112.png
# Saved extracted_images/image_113.png
# Saved extracted_images/image_114.png
# Saved extracted_images/image_115.png
# Saved extracted_images/image_116.png
# Saved extracted_images/image_117.png
# Saved extracted_images/image_118.png
# Saved extracted_images/image_119.png
# Saved extracted_images/image_120.png
# Saved extracted_images/image_121.png
# Saved extracted_images/image_122.png
# Saved extracted_images/image_123.png
# Saved extracted_images/image_124.png
# Saved extracted_images/image_125.png
# Saved extracted_images/image_126.png
# Saved extracted_images/image_127.png
# Saved extracted_images/image_128.png
# Saved extracted_images/image_129.png
# Saved extracted_images/image_130.png
# Saved extracted_images/image_131.png
# Saved extracted_images/image_132.png
# Saved extracted_images/image_133.png
# Saved extracted_images/image_134.png
# Saved extracted_images/image_135.png
# Saved extracted_images/image_136.png
# Saved extracted_images/image_137.png
# Saved extracted_images/image_138.png
# Saved extracted_images/image_139.png
# Saved extracted_images/image_140.png
# Saved extracted_images/image_141.png
# Saved extracted_images/image_142.png
# Saved extracted_images/image_143.png
# Saved extracted_images/image_144.png
# Saved extracted_images/image_145.png
# Saved extracted_images/image_146.png
# Saved extracted_images/image_147.png
# Saved extracted_images/image_148.png
# Saved extracted_images/image_149.png
# Saved extracted_images/image_150.png
# Saved extracted_images/image_151.png
# Saved extracted_images/image_152.png
# Saved extracted_images/image_153.png
# Saved extracted_images/image_154.png
# Saved extracted_images/image_155.png
# Saved extracted_images/image_156.png
# Saved extracted_images/image_157.png
# Saved extracted_images/image_158.png
# Saved extracted_images/image_159.png
# Saved extracted_images/image_160.png
# Saved extracted_images/image_161.png
# Saved extracted_images/image_162.png
# Saved extracted_images/image_163.png
# Saved extracted_images/image_164.png
# Saved extracted_images/image_165.png
# Saved extracted_images/image_166.png
# Saved extracted_images/image_167.png
# Saved extracted_images/image_168.png
# Saved extracted_images/image_169.png
# Saved extracted_images/image_170.png
# Saved extracted_images/image_171.png
# Saved extracted_images/image_172.png
# Saved extracted_images/image_173.png
# Saved extracted_images/image_174.png
# Saved extracted_images/image_175.png
# Saved extracted_images/image_176.png
# Saved extracted_images/image_177.png
# Saved extracted_images/image_178.png
# Saved extracted_images/image_179.png
# Saved extracted_images/image_180.png
# Saved extracted_images/image_181.png
# Saved extracted_images/image_182.png
# Saved extracted_images/image_183.png
# Saved extracted_images/image_184.png
# Saved extracted_images/image_185.png
# Saved extracted_images/image_186.png
# Saved extracted_images/image_187.png
# Saved extracted_images/image_188.png
# Saved extracted_images/image_189.png
# Saved extracted_images/image_190.png
# Saved extracted_images/image_191.png
# Saved extracted_images/image_192.png
# Saved extracted_images/image_193.png
# Saved extracted_images/image_194.png

# %%
from pdf2image import convert_from_path
import os

def extract_page_images(pdf_path, output_folder="pages_as_images"):
    os.makedirs(output_folder, exist_ok=True)

    pages = convert_from_path(pdf_path)
    for i, page in enumerate(pages):
        page_path = os.path.join(output_folder, f"page_{i+1}.png")
        page.save(page_path, "PNG")
        print(f"Saved {page_path}")

# Example
extract_page_images("/home/smayan/Desktop/Research-Paper-Analyst/downloads/1906.00744v5.pdf")
# Out:
# Saved pages_as_images/page_1.png
# Saved pages_as_images/page_2.png
# Saved pages_as_images/page_3.png
# Saved pages_as_images/page_4.png
# Saved pages_as_images/page_5.png
# Saved pages_as_images/page_6.png
# Saved pages_as_images/page_7.png
# Saved pages_as_images/page_8.png
# Saved pages_as_images/page_9.png
# Saved pages_as_images/page_10.png
# Saved pages_as_images/page_11.png
# Saved pages_as_images/page_12.png
# Saved pages_as_images/page_13.png
# Saved pages_as_images/page_14.png
# Saved pages_as_images/page_15.png
# Saved pages_as_images/page_16.png
# Saved pages_as_images/page_17.png
# Saved pages_as_images/page_18.png
# Saved pages_as_images/page_19.png

# %%
import os
import fitz  # PyMuPDF

def safe_pixmap_from_bytes(image_bytes):
    """Try multiple ways to load damaged or low-quality image streams."""
    try:
        return fitz.Pixmap(image_bytes)
    except:
        pass

    # try removing alpha or strange channels
    try:
        pix = fitz.Pixmap(image_bytes)
        if pix.alpha:
            return fitz.Pixmap(pix, 0)
        return pix
    except:
        pass

    # final fallback: wrap into a PNG container
    try:
        from PIL import Image
        import io

        img = Image.open(io.BytesIO(image_bytes))
        buf = io.BytesIO()
        img.save(buf, format="PNG")
        return fitz.Pixmap(buf.getvalue())
    except:
        return None


def recover_image(doc, img):
    """Handle SMask, ColorSpace, damaged images, and corrupted streams."""
    xref = img[0]
    smask = img[1]

    # ---- CASE 1: /SMask soft-mask ----
    if smask > 0:
        try:
            base = doc.extract_image(xref)["image"]
            mask = doc.extract_image(smask)["image"]

            pix_base = safe_pixmap_from_bytes(base)
            pix_mask = safe_pixmap_from_bytes(mask)

            if pix_base is None:
                return None

            try:
                pix = fitz.Pixmap(pix_base, pix_mask)
            except:
                pix = pix_base  # fallback

            ext = "png" if pix_base.n <= 3 else "pam"
            return {"ext": ext, "image": pix.tobytes(ext)}

        except:
            pass  # fallback below

    # ---- CASE 2: /ColorSpace conversion ----
    try:
        if "/ColorSpace" in doc.xref_object(xref, compressed=True):
            pix = fitz.Pixmap(doc, xref)
            pix = fitz.Pixmap(fitz.csRGB, pix)
            return {"ext": "png", "image": pix.tobytes("png")}
    except:
        pass

    # ---- CASE 3: Normal extraction ----
    try:
        return doc.extract_image(xref)
    except:
        pass

    # ---- CASE 4: *Last resort* fallback using Pixmap reconstruction ----
    try:
        raw = doc.xref_stream(xref)
        if raw:
            pix = safe_pixmap_from_bytes(raw)
            if pix:
                return {"ext": "png", "image": pix.tobytes("png")}
    except:
        pass

    return None  # fully unrecoverable


def extract_images(pdf_path, output_dir="output"):
    """Extract all embedded images from the provided PDF path (very robust)."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    print(f"Loading PDF: {pdf_path}")
    doc = fitz.open(pdf_path)

    seen = set()
    count = 0

    print(f"Total pages: {doc.page_count}")

    for page_index in range(doc.page_count):
        print(f"\n--- Page {page_index+1}/{doc.page_count} ---")
        images = doc.get_page_images(page_index, full=True)

        for img in images:
            xref = img[0]
            if xref in seen:
                continue

            data = recover_image(doc, img)
            if not data:
                print(f"Skipping xref {xref} (unrecoverable image)")
                continue

            ext = data["ext"]
            img_bytes = data["image"]

            filename = os.path.join(output_dir, f"img{xref:05d}.{ext}")
            try:
                with open(filename, "wb") as f:
                    f.write(img_bytes)
                print(f"Saved: {filename}")
                count += 1
            except:
                print(f"Failed saving xref {xref}")

            seen.add(xref)

    print(f"\n======================================")
    print(f"DONE. Extracted {count} images")
    print(f"Saved to folder: {output_dir}")
    print("======================================")

extract_images("/home/smayan/Desktop/Research-Paper-Analyst/downloads/2006.05474v2.pdf")
# Out:
# Loading PDF: /home/smayan/Desktop/Research-Paper-Analyst/downloads/2006.05474v2.pdf
# Total pages: 5
#
# --- Page 1/5 ---
#
# --- Page 2/5 ---
#
# --- Page 3/5 ---
#
# --- Page 4/5 ---
#
# --- Page 5/5 ---
#
# ======================================
# DONE. Extracted 0 images
# Saved to folder: output
# ======================================

# %%
# STEP 1
# import libraries
import fitz  # PyMuPDF
import io
from PIL import Image

# STEP 2
# file path you want to extract images from
file = "/home/smayan/Desktop/Research-Paper-Analyst/downloads/1906.00744v5.pdf"

# open the file
pdf_file = fitz.open(file)

# STEP 3
# iterate over PDF pages
for page_index in range(len(pdf_file)):

    # get the page itself
    page = pdf_file.load_page(page_index)  # load the page
    image_list = page.get_images(full=True)  # get images on the page

    # printing number of images found in this page
    if image_list:
        print(f"[+] Found a total of {len(image_list)} images on page {page_index}")
    else:
        print("[!] No images found on page", page_index)
    
    for image_index, img in enumerate(image_list, start=1):
        # get the XREF of the image
        xref = img[0]

        # extract the image bytes
        base_image = pdf_file.extract_image(xref)
        image_bytes = base_image["image"]

        # get the image extension
        image_ext = base_image["ext"]

        # save the image
        image_name = f"image{page_index+1}_{image_index}.{image_ext}"
        with open(image_name, "wb") as image_file:
            image_file.write(image_bytes)
            print(f"[+] Image saved as {image_name}")
# Out:
# [!] No images found on page 0
# [+] Found a total of 2 images on page 1
# [+] Image saved as image2_1.png
# [+] Image saved as image2_2.png
# [!] No images found on page 2
# [+] Found a total of 15 images on page 3
# [+] Image saved as image4_1.png
# [+] Image saved as image4_2.png
# [+] Image saved as image4_3.png
# [+] Image saved as image4_4.png
# [+] Image saved as image4_5.png
# [+] Image saved as image4_6.png
# [+] Image saved as image4_7.png
# [+] Image saved as image4_8.png
# [+] Image saved as image4_9.png
# [+] Image saved as image4_10.png
# [+] Image saved as image4_11.png
# [+] Image saved as image4_12.png
# [+] Image saved as image4_13.png
# [+] Image saved as image4_14.png
# [+] Image saved as image4_15.png
# [+] Found a total of 38 images on page 4
# [+] Image saved as image5_1.png
# [+] Image saved as image5_2.png
# [+] Image saved as image5_3.png
# [+] Image saved as image5_4.png
# [+] Image saved as image5_5.png
# [+] Image saved as image5_6.png
# [+] Image saved as image5_7.png
# [+] Image saved as image5_8.png
# [+] Image saved as image5_9.png
# [+] Image saved as image5_10.png
# [+] Image saved as image5_11.png
# [+] Image saved as image5_12.png
# [+] Image saved as image5_13.png
# [+] Image saved as image5_14.png
# [+] Image saved as image5_15.png
# [+] Image saved as image5_16.png
# [+] Image saved as image5_17.png
# [+] Image saved as image5_18.png
# [+] Image saved as image5_19.png
# [+] Image saved as image5_20.png
# [+] Image saved as image5_21.png
# [+] Image saved as image5_22.png
# [+] Image saved as image5_23.png
# [+] Image saved as image5_24.png
# [+] Image saved as image5_25.png
# [+] Image saved as image5_26.png
# [+] Image saved as image5_27.png
# [+] Image saved as image5_28.png
# [+] Image saved as image5_29.png
# [+] Image saved as image5_30.png
# [+] Image saved as image5_31.png
# [+] Image saved as image5_32.png
# [+] Image saved as image5_33.png
# [+] Image saved as image5_34.png
# [+] Image saved as image5_35.png
# [+] Image saved as image5_36.png
# [+] Image saved as image5_37.png
# [+] Image saved as image5_38.png
# [!] No images found on page 5
# [!] No images found on page 6
# [!] No images found on page 7
# [!] No images found on page 8
# [!] No images found on page 9
# [+] Found a total of 7 images on page 10
# [+] Image saved as image11_1.png
# [+] Image saved as image11_2.png
# [+] Image saved as image11_3.png
# [+] Image saved as image11_4.png
# [+] Image saved as image11_5.png
# [+] Image saved as image11_6.png
# [+] Image saved as image11_7.png
# [!] No images found on page 11
# [!] No images found on page 12
# [!] No images found on page 13
# [+] Found a total of 14 images on page 14
# [+] Image saved as image15_1.png
# [+] Image saved as image15_2.png
# [+] Image saved as image15_3.png
# [+] Image saved as image15_4.png
# [+] Image saved as image15_5.png
# [+] Image saved as image15_6.png
# [+] Image saved as image15_7.png
# [+] Image saved as image15_8.png
# [+] Image saved as image15_9.png
# [+] Image saved as image15_10.png
# [+] Image saved as image15_11.png
# [+] Image saved as image15_12.png
# [+] Image saved as image15_13.png
# [+] Image saved as image15_14.png
# [!] No images found on page 15
# [!] No images found on page 16
# [!] No images found on page 17
# [+] Found a total of 118 images on page 18
# [+] Image saved as image19_1.png
# [+] Image saved as image19_2.png
# [+] Image saved as image19_3.png
# [+] Image saved as image19_4.png
# [+] Image saved as image19_5.png
# [+] Image saved as image19_6.png
# [+] Image saved as image19_7.png
# [+] Image saved as image19_8.png
# [+] Image saved as image19_9.png
# [+] Image saved as image19_10.png
# [+] Image saved as image19_11.png
# [+] Image saved as image19_12.png
# [+] Image saved as image19_13.png
# [+] Image saved as image19_14.png
# [+] Image saved as image19_15.png
# [+] Image saved as image19_16.png
# [+] Image saved as image19_17.png
# [+] Image saved as image19_18.png
# [+] Image saved as image19_19.png
# [+] Image saved as image19_20.png
# [+] Image saved as image19_21.png
# [+] Image saved as image19_22.png
# [+] Image saved as image19_23.png
# [+] Image saved as image19_24.png
# [+] Image saved as image19_25.png
# [+] Image saved as image19_26.png
# [+] Image saved as image19_27.png
# [+] Image saved as image19_28.png
# [+] Image saved as image19_29.png
# [+] Image saved as image19_30.png
# [+] Image saved as image19_31.png
# [+] Image saved as image19_32.png
# [+] Image saved as image19_33.png
# [+] Image saved as image19_34.png
# [+] Image saved as image19_35.png
# [+] Image saved as image19_36.png
# [+] Image saved as image19_37.png
# [+] Image saved as image19_38.png
# [+] Image saved as image19_39.png
# [+] Image saved as image19_40.png
# [+] Image saved as image19_41.png
# [+] Image saved as image19_42.png
# [+] Image saved as image19_43.png
# [+] Image saved as image19_44.png
# [+] Image saved as image19_45.png
# [+] Image saved as image19_46.png
# [+] Image saved as image19_47.png
# [+] Image saved as image19_48.png
# [+] Image saved as image19_49.png
# [+] Image saved as image19_50.png
# [+] Image saved as image19_51.png
# [+] Image saved as image19_52.png
# [+] Image saved as image19_53.png
# [+] Image saved as image19_54.png
# [+] Image saved as image19_55.png
# [+] Image saved as image19_56.png
# [+] Image saved as image19_57.png
# [+] Image saved as image19_58.png
# [+] Image saved as image19_59.png
# [+] Image saved as image19_60.png
# [+] Image saved as image19_61.png
# [+] Image saved as image19_62.png
# [+] Image saved as image19_63.png
# [+] Image saved as image19_64.png
# [+] Image saved as image19_65.png
# [+] Image saved as image19_66.png
# [+] Image saved as image19_67.png
# [+] Image saved as image19_68.png
# [+] Image saved as image19_69.png
# [+] Image saved as image19_70.png
# [+] Image saved as image19_71.png
# [+] Image saved as image19_72.png
# [+] Image saved as image19_73.png
# [+] Image saved as image19_74.png
# [+] Image saved as image19_75.png
# [+] Image saved as image19_76.png
# [+] Image saved as image19_77.png
# [+] Image saved as image19_78.png
# [+] Image saved as image19_79.png
# [+] Image saved as image19_80.png
# [+] Image saved as image19_81.png
# [+] Image saved as image19_82.png
# [+] Image saved as image19_83.png
# [+] Image saved as image19_84.png
# [+] Image saved as image19_85.png
# [+] Image saved as image19_86.png
# [+] Image saved as image19_87.png
# [+] Image saved as image19_88.png
# [+] Image saved as image19_89.png
# [+] Image saved as image19_90.png
# [+] Image saved as image19_91.png
# [+] Image saved as image19_92.png
# [+] Image saved as image19_93.png
# [+] Image saved as image19_94.png
# [+] Image saved as image19_95.png
# [+] Image saved as image19_96.png
# [+] Image saved as image19_97.png
# [+] Image saved as image19_98.png
# [+] Image saved as image19_99.png
# [+] Image saved as image19_100.png
# [+] Image saved as image19_101.png
# [+] Image saved as image19_102.png
# [+] Image saved as image19_103.png
# [+] Image saved as image19_104.png
# [+] Image saved as image19_105.png
# [+] Image saved as image19_106.png
# [+] Image saved as image19_107.png
# [+] Image saved as image19_108.png
# [+] Image saved as image19_109.png
# [+] Image saved as image19_110.png
# [+] Image saved as image19_111.png
# [+] Image saved as image19_112.png
# [+] Image saved as image19_113.png
# [+] Image saved as image19_114.png
# [+] Image saved as image19_115.png
# [+] Image saved as image19_116.png
# [+] Image saved as image19_117.png
# [+] Image saved as image19_118.png
